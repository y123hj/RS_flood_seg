# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import glob
from osgeo import gdal, ogr

# %%
def clip_raster_with_geojson(input_raster, output_clipped_raster, geojson_file):
    # Open the input raster
    input_ds = gdal.Open(input_raster)

    # Open the GeoJSON file
    geojson_ds = ogr.Open(geojson_file)
    layer = geojson_ds.GetLayer()

    # Create a new raster dataset for the clipped output
    clipped_ds = gdal.Warp(output_clipped_raster, input_ds, cutlineDSName=geojson_file, cropToCutline=True, dstNodata=0)

    # Close the datasets
    input_ds = None
    geojson_ds = None
    clipped_ds = None

# %%
# 文件路径和列表
image_path = '/content/drive/MyDrive/RS/S2_all_bands/'
json_path = '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/'
image_list = glob.glob(image_path+'*.tif')
json_list = glob.glob(json_path+'*')
image_list = sorted(image_list)
json_list = sorted(json_list)[:-1]  # 除去最后一个整体的json文件
print(image_list)
print(json_list)
# Out:
# ['/content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000024064-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000036096-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000012032-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000024064-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000024064-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/India_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/India_ALL_Bands-0000000000-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/India_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/India_ALL_Bands-0000012032-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Mekong_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Mekong_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Nigeria_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Nigeria_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000000000-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000012032-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000024064-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000024064-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000036096-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000036096-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000048128-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Pakistan_ALL_Bands-0000048128-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Paraguay_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Paraguay_ALL_Bands-0000000000-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Paraguay_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Paraguay_ALL_Bands-0000012032-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Somalia_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Somalia_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Somalia_ALL_Bands-0000024064-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Span_ALL_Bands.tif', '/content/drive/MyDrive/RS/S2_all_bands/Sri_Lanka_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Sri_Lanka_ALL_Bands-0000000000-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/Sri_Lanka_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/Sri_Lanka_ALL_Bands-0000012032-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/USA_ALL_Bands-0000000000-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/USA_ALL_Bands-0000000000-0000012032.tif', '/content/drive/MyDrive/RS/S2_all_bands/USA_ALL_Bands-0000012032-0000000000.tif', '/content/drive/MyDrive/RS/S2_all_bands/USA_ALL_Bands-0000012032-0000012032.tif']
# ['/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_103757_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_129334_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_195474_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_23014_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_233925_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_242570_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_290290_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_294583_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_312675_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_314919_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_360519_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_379434_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_432776_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_60373_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Bolivia_76104_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_103272_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_1033830_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_1078550_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_1089161_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_11745_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_124834_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_128663_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_132163_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_134751_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_135389_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_141271_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_141910_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_142312_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_144050_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_146222_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_147015_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_154838_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_156478_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_161233_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_167233_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_168875_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_187318_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_194723_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_234935_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_247288_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_24858_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_label/Ghana_26376_label', '/content/drive/MyDrive/RS/S1_all_bands/sen1floods11_hand_labeled_ ...

# %%
for i in range(len(image_list)):
    raster_path = image_list[i]    # 栅格路径
    raster_ds = gdal.Open(raster_path)  # 栅格数据集
    geotransform = raster_ds.GetGeoTransform()
    # print(geotransform)
    min_x = geotransform[0]     # 栅格数据集范围
    max_x = geotransform[0] + geotransform[1] * raster_ds.RasterXSize
    min_y = geotransform[3] + geotransform[5] * raster_ds.RasterYSize
    max_y = geotransform[3]


    for j in range(len(json_list)):
        geojson_path = glob.glob(json_list[j]+'/*.json')[0]    # 矢量路径
        geojson_ds = ogr.Open(geojson_path)     # 矢量数据集
        geojson_layer = geojson_ds.GetLayer()
        geojson_extent = geojson_layer.GetExtent()      # 矢量数据集范围
        # print(geojson_extent)

        is_contained = (geojson_extent[0] >= min_x and  # 比较是否在范围内
                    geojson_extent[1] <= max_x and
                    geojson_extent[2] >= min_y and
                    geojson_extent[3] <= max_y)

        if is_contained:
            output_path = '/content/drive/MyDrive/RS/HAND/S2_split/' + os.listdir(json_list[j])[0][:-5] + '.tif'
            print(raster_path)
            print(output_path)
            clip_raster_with_geojson(raster_path, output_path, geojson_path)
# Out:
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_233925_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_242570_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_290290_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_294583_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_76104_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_103757_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_23014_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_360519_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_60373_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000024064-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_129334_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000024064-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_312675_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000024064-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_314919_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000024064-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_379434_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Bolivia_ALL_Bands-0000024064-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Bolivia_432776_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_1078550_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_1089161_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_11745_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_124834_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_135389_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_141271_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_141910_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_142312_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_147015_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_167233_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_187318_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_24858_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_308249_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_359826_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_362274_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_406026_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_495107_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_49890_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_53713_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_597288_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_61925_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_83200_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_868803_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_887131_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_953791_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000012032.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_144050_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000012032.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_161233_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000000000-0000012032.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_97516_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_103272_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_1033830_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_128663_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_132163_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_134751_label.tif
# /content/drive/MyDrive/RS/S2_all_bands/Ghana_ALL_Bands-0000012032-0000000000.tif
# /content/drive/MyDrive/RS/HAND/S2_split/Ghana_156478_label.tif
